# %% [markdown]
# # Develop Model Driver
# In this notebook we will develop the API that will call our model. We need it to initialise the model and transform the input from the Flask app so that it is in the appropriate format to call the model. We expect the input to be JSON that will have the image encoded as a base64 string. The code below uses the writefile magic to write the contents of the cell to the file driver.py

# %%
# %%writefile driver.py
import base64
import json
import logging
import os
import timeit as t
from io import BytesIO

import numpy as np
import tensorflow as tf
from PIL import Image, ImageOps
from tensorflow.contrib.slim.nets import resnet_v1

_MODEL_FILE = os.getenv('MODEL_FILE', "resnet_v1_152.ckpt")
_LABEL_FILE = os.getenv('LABEL_FILE', "synset.txt")
_NUMBER_RESULTS = 3


def _create_label_lookup(label_path):
    with open(label_path, 'r') as f:
        label_list = [l.rstrip() for l in f]
        
    def _label_lookup(*label_locks):
        return [label_list[l] for l in label_locks]
    
    return _label_lookup


def _load_tf_model(checkpoint_file):
    # Placeholder
    input_tensor = tf.placeholder(tf.float32, shape=(None,224,224,3), name='input_image')
    
    # Load the model
    sess = tf.Session()
    arg_scope = resnet_v1.resnet_arg_scope()
    with tf.contrib.slim.arg_scope(arg_scope):
        logits, _ = resnet_v1.resnet_v1_152(input_tensor, num_classes=1000, is_training=False, reuse=tf.AUTO_REUSE)
    probabilities = tf.nn.softmax(logits)
    
    saver = tf.train.Saver()
    saver.restore(sess, checkpoint_file)
    
    def predict_for(image):
        pred, pred_proba = sess.run([logits,probabilities], feed_dict={input_tensor: image})
        return pred_proba
    
    return predict_for


def _base64img_to_numpy(base64_img_string):
    if base64_img_string.startswith('b\''):
        base64_img_string = base64_img_string[2:-1]
    base64Img = base64_img_string.encode('utf-8')

    # Preprocess the input data 
    startPreprocess = t.default_timer()
    decoded_img = base64.b64decode(base64Img)
    img_buffer = BytesIO(decoded_img)

    # Load image with PIL (RGB)
    pil_img = Image.open(img_buffer).convert('RGB')
    pil_img = ImageOps.fit(pil_img, (224, 224), Image.ANTIALIAS)
    return np.array(pil_img, dtype=np.float32)


def create_scoring_func(model_path=_MODEL_FILE, label_path=_LABEL_FILE):
    logger = logging.getLogger("model_driver")
    
    start = t.default_timer()
    labels_for = _create_label_lookup(label_path)
    predict_for = _load_tf_model(model_path)
    end = t.default_timer()

    loadTimeMsg = "Model loading time: {0} ms".format(round((end-start)*1000, 2))
    logger.info(loadTimeMsg)
    
    def call_model(image_array, number_results=_NUMBER_RESULTS):
        pred_proba = predict_for(image_array).squeeze()
        selected_results = np.flip(np.argsort(pred_proba), 0)[:number_results]
        labels = labels_for(*selected_results)
        return list(zip(labels, pred_proba[selected_results].astype(np.float64)))
    return call_model


def get_model_api():
    logger = logging.getLogger("model_driver")
    scoring_func = create_scoring_func()
    
    def process_and_score(images_dict, number_results=_NUMBER_RESULTS):
        start = t.default_timer()

        results = {}
        for key, base64_img_string in images_dict.items():
            rgb_image = _base64img_to_numpy(base64_img_string)
            batch_image = np.expand_dims(rgb_image, 0)
            results[key]=scoring_func(batch_image, number_results=_NUMBER_RESULTS)
        
        end = t.default_timer()

        logger.info("Predictions: {0}".format(results))
        logger.info("Predictions took {0} ms".format(round((end-start)*1000, 2)))
        return (results, 'Computed in {0} ms'.format(round((end-start)*1000, 2)))
    return process_and_score

def version():
    return tf.__version__
# Out:
# Writing driver.py

# %%
import logging

# %%
logging.basicConfig(level=logging.DEBUG)

# %% [markdown]
# We run the file driver.py which will be everything into the context of the notebook.

# %%
# %run driver.py

# %% [markdown]
# We will use the same Lynx image we used ealier to check that our driver works as expected.

# %%
from testing_utilities import img_url_to_json
# Out:
# DEBUG:matplotlib:$HOME=/home/mabou
# DEBUG:matplotlib:matplotlib data path /anaconda/envs/AKSDeployment/lib/python3.5/site-packages/matplotlib/mpl-data
# DEBUG:matplotlib:loaded rc file /anaconda/envs/AKSDeployment/lib/python3.5/site-packages/matplotlib/mpl-data/matplotlibrc
# DEBUG:matplotlib:matplotlib version 2.2.2
# DEBUG:matplotlib:interactive is False
# DEBUG:matplotlib:platform is linux
# DEBUG:matplotlib:loaded modules: ['tensorflow.contrib.distributions.python.ops.geometric', 'tensorflow.python.ops.histogram_ops', 'tensorflow.contrib.quantize.python.common', 'tensorflow.contrib.optimizer_v2', 'tensorflow.python.summary.writer.event_file_writer_v2', 'tensorflow.contrib.data.python.ops.readers', 'cryptography.hazmat.backends.openssl.ciphers', '_locale', 'tensorflow.contrib.distributions.python.ops.moving_stats', 'IPython.terminal.ipapp', 'tensorflow.python.ops.variable_scope', 'asn1crypto', 'tensorflow.core.protobuf.control_flow_pb2', 'tensorflow.python.ops.linalg.linear_operator_util', 'tensorflow.contrib.distributions.python.ops.onehot_categorical', 'pexpect', 'tensorflow.contrib.framework.python.ops.checkpoint_ops', 'jupyter_client.manager', 'tensorflow.keras.applications.vgg19', 'xml.dom.domreg', 'tensorflow.python.ops.gen_ctc_ops', 'prompt_toolkit.key_binding.digraphs', 'tensorflow.contrib.gan.python.features.python.clip_weights_impl', 'tensorflow.python.framework.random_seed', 'IPython.core.latex_symbols', 'IPython.core.usage', 'tensorflow.distributions', 'tensorflow.contrib.slim.python.slim.nets.overfeat', 'tensorflow.core.protobuf.rewriter_config_pb2', 'chardet.sbcharsetprober', 'code', 'tensorflow.contrib.cudnn_rnn', '_cython_0_28_4', 'tensorflow.contrib.slim.python.slim.data.data_provider', 'prompt_toolkit.filters', 'zmq.sugar.socket', 'tensorflow.python.framework.cpp_shape_inference_pb2', 'tensorflow.python.summary.text_summary', 'numpy._globals', 'tensorflow.core.util.event_pb2', 'prompt_toolkit.key_binding.bindings.completion', 'jupyter_client.channels', 'tensorflow.contrib.distributions.python.ops.autoregressive', 'zmq.backend.cython.message', 'tensorflow.python.keras.layers.noise', 'prompt_toolkit.cache', 'IPython.utils.tempdir', 'prompt_toolkit.layout.controls', 'tensorflow.python.ops.distributions.laplace', 'tensorflow.python.estimator.canned', 'tensorflow.contrib.quantize', 'tensorflow.python.profiler.internal', 'tensorflow.contrib.slim.python.slim.nets.inception_v2', 'tensorflow.contrib.kfac.python.ops.linear_operator', 'tensorflow.contrib.resampler', 'absl.flags._exceptions', 'tensorflow.contrib.graph_editor.edit', 'tensorflow.python.training.monitored_session', 'prompt_toolkit.key_binding.bindings.named_commands', 'tensorflow.contrib.input_pipeline.python.ops.input_pipeline_ops', 'base64', 'tensorflow.python.platform.resource_loader', 'urllib3.contrib', 'tensorflow.core.framework.tensor_description_pb2', 'requests.packages.chardet.jisfreq', 'requests.packages.urllib3.poolmanager', 'tensorflow.contrib.tpu.ops', 'tensorflow.python.training.warm_starting_util', 'gettext', 'xml.parsers.expat.errors', 'tensorflow.python.saved_model.saved_model', 'parso.python.diff', 'tensorflow.python.ops.summary_ops_v2', 'zmq.eventloop.ioloop', 'tensorflow.contrib.bayesflow', 'idna.idnadata', 'requests.packages.chardet.mbcharsetprober', 'tensorflow.contrib.util', 'tensorflow.contrib.image.python.ops.dense_image_warp', 'tensorflow.contrib.input_pipeline.python', 'pyexpat', '_bisect', 'runpy', 'tensorflow.contrib.learn', 'numpy.testing.decorators', 'tensorflow.core.framework.device_attributes_pb2', 'tensorflow.python.ops.session_ops', 'tensorflow.python.eager.execute', 'tensorflow.contrib.tensorboard.plugins.projector.projector_config_pb2', 'tensorflow.python.training.input', 'tensorflow.python.ops.string_ops', 'tensorflow.contrib.quantization.python', 'tensorflow.keras.backend', 'tensorflow.contrib.data.python.ops.enumerate_ops', 'numpy.core.fromnumeric', 'jupyter_client.clientabc', 'tensorflow.contrib.tpu.python.tpu.tpu_feed', 'tensorflow.contrib.keras.api', 'requests.packages.chardet.euctwfreq', 'ea03fd70901ff898cdf6c10a3919ed5a', 'tensorflow.python.estimator.export', 'absl', 'tensorflow.contrib.gan.python.losses.python.tuple_losses_impl', 'tensorflow.contrib.tpu.python.tpu.bfloat16', 'tensorflow.python.keras.datasets.fashion_mnist', 'typing', 'tensorflow.contrib.learn.python.learn.estimators', 'IPython.core.p ...
# DEBUG:matplotlib:CACHEDIR=/home/mabou/.cache/matplotlib
# DEBUG:matplotlib.font_manager:Using fontManager instance from /home/mabou/.cache/matplotlib/fontList.json
# DEBUG:matplotlib.backends:backend module://ipykernel.pylab.backend_inline version unknown
# DEBUG:matplotlib.backends:backend module://ipykernel.pylab.backend_inline version unknown

# %%
IMAGEURL = "https://upload.wikimedia.org/wikipedia/commons/thumb/6/68/Lynx_lynx_poing.jpg/220px-Lynx_lynx_poing.jpg"

# %%
jsonimg = img_url_to_json(IMAGEURL)

# %%
json_lod= json.loads(jsonimg)

# %%
predict_for = get_model_api()
# Out:
# INFO:tensorflow:Restoring parameters from resnet_v1_152.ckpt
# INFO:model_driver:Model loading time: 11395.71 ms

# %%
output = predict_for(json_lod['input'])
# Out:
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'iCCP' 41 292
# DEBUG:PIL.PngImagePlugin:iCCP profile name b'ICC Profile'
# DEBUG:PIL.PngImagePlugin:Compression method 0
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 345 65536
# INFO:model_driver:Predictions: {'image': [('n02127052 lynx, catamount', 0.99745172262191772), ('n02128385 leopard, Panthera pardus', 0.0015076899435371161), ('n02128757 snow leopard, ounce, Panthera uncia', 0.00051647447980940342)]}
# INFO:model_driver:Predictions took 958.24 ms

# %% [markdown]
# The output of our prediction function is JSON that will be returned to our Flask app. It looks like our model predicted Lynx with over 99% probability.

# %%
json.dumps(output)
# Out:
# '[{"image": [["n02127052 lynx, catamount", 0.9974517226219177], ["n02128385 leopard, Panthera pardus", 0.001507689943537116], ["n02128757 snow leopard, ounce, Panthera uncia", 0.0005164744798094034]]}, "Computed in 958.24 ms"]'

# %% [markdown]
# We can move onto [building our docker image](02_BuildImage.ipynb)
